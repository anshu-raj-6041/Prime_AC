# %%
import pandas as pd

# %%
s = pd.Series([10,20,30,40,50])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s.name = "numbers"

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: numbers, dtype: int64

# %%
# indexing

s[0]
# Out:
# np.int64(10)

# %%
s[0:2]
# Out:
# 0    10
# 1    20
# Name: numbers, dtype: int64

# %%
s[2:4]
# Out:
# 2    30
# 3    40
# Name: numbers, dtype: int64

# %%
# iloc => location based indexing

s.iloc[3]   # value at index 3
# Out:
# np.int64(40)

# %%
s.iloc[[1,3,4]]
# Out:
# 1    20
# 3    40
# 4    50
# Name: numbers, dtype: int64

# %%
s.name = "calories"

# %%
index = ["apples", "banana", "grapes", "orange", "strawberry"]

# %%
s.index = index
s
# Out:
# apples        10
# banana        20
# grapes        30
# orange        40
# strawberry    50
# Name: calories, dtype: int64

# %%
s.iloc[3]
# Out:
# np.int64(40)

# %%
# loc => label based indexing
s.loc["grapes"]
# Out:
# np.int64(30)

# %%
# In label based indexing ur start as well as stop value both are included in the output

s["banana":"grapes"]
# Out:
# banana    20
# grapes    30
# Name: calories, dtype: int64

# %%
fruit_protein = {
    "Avocado": 2.0,
    "Guava": 2.6,
    "BlackBerry":2.0,
    "Orange": 0.9,
    "Banana":1.1,
    "Apples": 0.3
}

# %%
s2 = pd.Series(fruit_protein, name="protein")
s2
# Out:
# Avocado       2.0
# Guava         2.6
# BlackBerry    2.0
# Orange        0.9
# Banana        1.1
# Apples        0.3
# Name: protein, dtype: float64

# %%
# Conditional Selection

s2>1
# Out:
# Avocado        True
# Guava          True
# BlackBerry     True
# Orange        False
# Banana         True
# Apples        False
# Name: protein, dtype: bool

# %%
s2[s2>1]
# Out:
# Avocado       2.0
# Guava         2.6
# BlackBerry    2.0
# Banana        1.1
# Name: protein, dtype: float64

# %%
# logical operator (not, and, or)

# %%
# modifying the Series
s2["Apples"] = 5.2

# %% [markdown]
# #### Data Frame

# %%
data = {
    "Name": ["Anshu", "Rahul", "Priya", "Neha"],
    "Age": [21, 22, 20, 23],
    "Department": ["IT", "HR", "Finance", "Marketing"],
    "Salary": [50000, 45000, 48000, 52000]
}

# %%
data
# Out:
# {'Name': ['Anshu', 'Rahul', 'Priya', 'Neha'],
#  'Age': [21, 22, 20, 23],
#  'Department': ['IT', 'HR', 'Finance', 'Marketing'],
#  'Salary': [50000, 45000, 48000, 52000]}

# %%
df = pd.DataFrame(data)
df
# Out:
#     Name  Age Department  Salary
# 0  Anshu   21         IT   50000
# 1  Rahul   22         HR   45000
# 2  Priya   20    Finance   48000
# 3   Neha   23  Marketing   52000

# %%
df.head(2)
# Out:
#     Name  Age Department  Salary
# 0  Anshu   21         IT   50000
# 1  Rahul   22         HR   45000

# %%
df.tail(2)      # last 2 rows
# Out:
#     Name  Age Department  Salary
# 2  Priya   20    Finance   48000
# 3   Neha   23  Marketing   52000

# %%
# loc and iloc

df.iloc[1:3]
# Out:
#     Name  Age Department  Salary
# 1  Rahul   22         HR   45000
# 2  Priya   20    Finance   48000

# %%
df.loc[1:2, ["Age", "Department"]]
# Out:
#    Age Department
# 1   22         HR
# 2   20    Finance

# %%
df["Age"]
# Out:
# 0    21
# 1    22
# 2    20
# 3    23
# Name: Age, dtype: int64

# %%
df[["Age", "Department"]]
# Out:
#    Age Department
# 0   21         IT
# 1   22         HR
# 2   20    Finance
# 3   23  Marketing

# %%
df.drop("Age", axis=1)      # axis=1 mtlb pura column gone
# Out:
#     Name Department  Salary
# 0  Anshu         IT   50000
# 1  Rahul         HR   45000
# 2  Priya    Finance   48000
# 3   Neha  Marketing   52000

# %%
df
# Out:
#     Name  Age Department  Salary
# 0  Anshu   21         IT   50000
# 1  Rahul   22         HR   45000
# 2  Priya   20    Finance   48000
# 3   Neha   23  Marketing   52000

# %%
df.shape
# Out:
# (4, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        4 non-null      object
#  1   Age         4 non-null      int64
#  2   Department  4 non-null      object
#  3   Salary      4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 260.0+ bytes

# %%
# BroadCasting

df["Salary"] = df["Salary"]+100

# %%
df["Salary"]
# Out:
# 0    50100
# 1    45100
# 2    48100
# 3    52100
# Name: Salary, dtype: int64

# %%
# renaming columns:

df.rename(columns = {"Department": "Dept"}, inplace = True)

# %%
df
# Out:
#     Name  Age       Dept  Salary
# 0  Anshu   21         IT   50100
# 1  Rahul   22         HR   45100
# 2  Priya   20    Finance   48100
# 3   Neha   23  Marketing   52100

# %%
df["Salary"].unique()
# Out:
# array([50100, 45100, 48100, 52100])

# %%
df["Dept"].value_counts()
# Out:
# Dept
# IT           1
# HR           1
# Finance      1
# Marketing    1
# Name: count, dtype: int64

# %%
df["Promoted Salary"] = df["Salary"] * 10
df
# Out:
#     Name  Age       Dept  Salary  Promoted Salary
# 0  Anshu   21         IT   50100           501000
# 1  Rahul   22         HR   45100           451000
# 2  Priya   20    Finance   48100           481000
# 3   Neha   23  Marketing   52100           521000

# %%
df
# Out:
#     Name  Age       Dept  Salary  Promoted Salary
# 0  Anshu   21         IT   50100           501000
# 1  Rahul   22         HR   45100           451000
# 2  Priya   20    Finance   48100           481000
# 3   Neha   23  Marketing   52100           521000

# %% [markdown]
# #### Data Cleaning

# %%
df.isnull().sum()
# Out:
# Name               0
# Age                0
# Dept               0
# Salary             0
# Promoted Salary    0
# dtype: int64

# %%
data = {
    "Name": ["Anshu", "Rahul", "Priya", "Neha"],
    "Age": [21, 22, 20, 23],
    "Department": ["IT", "HR", "Finance", "Marketing"],
    "Salary": [50000, 45000, 48000, 52000]
}

# %%
df
# Out:
#     Name  Age       Dept  Salary  Promoted Salary
# 0  Anshu   21         IT   50100           501000
# 1  Rahul   22         HR   45100           451000
# 2  Priya   20    Finance   48100           481000
# 3   Neha   23  Marketing   52100           521000

# %%
df.isnull().sum()
# Out:
# Name               0
# Age                0
# Dept               0
# Salary             0
# Promoted Salary    0
# dtype: int64
